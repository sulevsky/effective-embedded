# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Total

# %%
df = pd.read_csv("experiment_results/output.csv")

# %%
df.describe()
# Out:
#                raw  measured_voltage
# count   320.000000        320.000000
# mean   2374.753125       1913.293750
# std    1498.886732       1207.930786
# min       0.000000          0.000000
# 25%    1053.750000        848.250000
# 50%    2296.500000       1850.000000
# 75%    3860.500000       3110.500000
# max    4095.000000       3300.000000

# %% [markdown]
# ### Experiments

# %%
print(f"Number of samples: {len(df)}")
print(f"Measured max voltage with voltmeter: 3316")
print(f"Max voltage: {max(df["measured_voltage"])}")
plt.plot(df["raw"], df["measured_voltage"], marker='.')
plt.xlabel("Raw ADC (bin)")
plt.ylabel("Voltage (mV)")
plt.title(f"Voltage vs Raw ADC")
plt.grid(True)
plt.show()
# Out:
# Number of samples: 320
# Measured max voltage with voltmeter: 3316
# Max voltage: 3300
